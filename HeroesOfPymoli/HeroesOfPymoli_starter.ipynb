# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to Change These)
file_to_load = "Resources/purchase_data.csv"

# Read Purchasing File and store into Pandas data frame
purchase_data_df = pd.read_csv(file_to_load)

# %% [markdown]
# ## Player Count

# %% [markdown]
# * Display the total number of players

# %%
players = purchase_data_df['SN'].count()
purchase_data_df.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %% [markdown]
# ## Purchasing Analysis (Total)

# %% [markdown]
# * Run basic calculations to obtain number of unique items, average price, etc.
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
uni_items = len((purchase_data_df['Item ID']).unique())
total_rev = (purchase_data_df['Price'].sum())
tot_purch = (purchase_data_df['Purchase ID'].count())
avg_price = (purchase_data_df["Price"].mean())

data = {'Unique Items': [uni_items],
       'Average Price': [avg_price],
       'Number of Purchases': [tot_purch],
       'Total Revenue': [total_rev]}

summary_df = pd.DataFrame(data, columns = ['Unique Items','Average Price','Number of Purchases','Total Revenue'])
summary_df
# Out:
#    Unique Items  Average Price  Number of Purchases  Total Revenue
# 0           179       3.050987                  780        2379.77

# %% [markdown]
# ## Gender Demographics

# %% [markdown]
# * Percentage and Count of Male Players
#
#
# * Percentage and Count of Female Players
#
#
# * Percentage and Count of Other / Non-Disclosed

# %%
gender_group= purchase_data_df.groupby(["Gender"])
uni_gender_df = gender_group.nunique()
total_gender = uni_gender_df["SN"].sum()

count = uni_gender_df["SN"].unique()
percentage = uni_gender_df["SN"]/ total_gender

gender_df = pd.DataFrame({"Percentage of Players": percentage,
                            "Total Count":count})
gender_df["Percentage of Players"] = gender_df["Percentage of Players"].map("{:,.2%}".format)
gender_df
# Out:
#                       Percentage of Players  Total Count
# Gender
# Female                               14.06%           81
# Male                                 84.03%          484
# Other / Non-Disclosed                 1.91%           11

# %% [markdown]
# ## Purchasing Analysis (Gender)

# %% [markdown]
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. by gender
#
#
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
purchase_count = gender_group["Gender"].count()
average_purchase_price = gender_group["Price"].mean()
total_purchase_value = gender_group["Price"].sum()
average_total_purchase_per_person = total_purchase_value / total_gender

purchasing_analysis_gender_df = pd.DataFrame({"Purchase Count": purchase_count,
                                              "Average Purchase Price": average_purchase_price,
                                              "Total Purchase Value": total_purchase_value,
                                              "Avg Total Purchase per Person": average_total_purchase_per_person                                             
                                              })
purchasing_analysis_gender_df.index.name = "Gender"
purchasing_analysis_gender_df
# Out:
#                        Purchase Count  Average Purchase Price  \
# Gender
# Female                            113                3.203009
# Male                              652                3.017853
# Other / Non-Disclosed              15                3.346000
#
#                        Total Purchase Value  Avg Total Purchase per Person
# Gender
# Female                               361.94                       0.628368
# Male                                1967.64                       3.416042
# Other / Non-Disclosed                 50.19                       0.087135

# %% [markdown]
# ## Age Demographics

# %% [markdown]
# * Establish bins for ages
#
#
# * Categorize the existing players using the age bins. Hint: use pd.cut()
#
#
# * Calculate the numbers and percentages by age group
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: round the percentage column to two decimal points
#
#
# * Display Age Demographics Table

# %%
bins = [1, 10, 15, 20, 25, 30, 35, 35, 40,100]
labels = ['<10', '10-14', '15-19', '20-24', '25-29', '30-34','35-39', '40+']

purchase_data_df['Age Range'] = pd.cut(purchase_data_df['Age'], bins, labels=labels, include_lowest = True, duplicates = 'drop')

age_range_df = purchase_data_df.groupby("Age Range")

age_total_count = age_range_df["SN"].nunique()

age_percentage_of_players = (age_total_count/players) * 100

age_demographics_df = pd.DataFrame({"Total Count":age_total_count,
                                    "Percentage of Players":age_percentage_of_players
                                    })
age_demographics_df
# Out:
#            Total Count  Percentage of Players
# Age Range
# <10                 24               3.076923
# 10-14               41               5.256410
# 15-19              150              19.230769
# 20-24              232              29.743590
# 25-29               59               7.564103
# 30-34               37               4.743590
# 35-39               26               3.333333
# 40+                  7               0.897436

# %% [markdown]
# ## Purchasing Analysis (Age)

# %% [markdown]
# * Bin the purchase_data data frame by age
#
#
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
purchase_count_age = age_range_df["Purchase ID"].count()
average_purchase_price_age = age_range_df["Price"].mean()
total_purchase_value_age = age_range_df["Price"].sum()

average_total_purchase_per_person = total_purchase_value_age/age_total_count

purchasing_analysis_age_df=pd.DataFrame({"Purchase Count":purchase_count_age,
                                         "Average Purchase Price":average_purchase_price_age,
                                         "Total Purchase Value":total_purchase_value_age, 
                                         "Avg Total Purchase per Person":average_total_purchase_per_person
                                        })
purchasing_analysis_age_df
# Out:
#            Purchase Count  Average Purchase Price  Total Purchase Value  \
# Age Range
# <10                    32                3.405000                108.96
# 10-14                  54                2.900000                156.60
# 15-19                 200                3.107800                621.56
# 20-24                 325                3.020431                981.64
# 25-29                  77                2.875584                221.42
# 30-34                  52                2.994423                155.71
# 35-39                  33                3.404545                112.35
# 40+                     7                3.075714                 21.53
#
#            Avg Total Purchase per Person
# Age Range
# <10                             4.540000
# 10-14                           3.819512
# 15-19                           4.143733
# 20-24                           4.231207
# 25-29                           3.752881
# 30-34                           4.208378
# ...

# %% [markdown]
# ## Top Spenders

# %% [markdown]
# * Run basic calculations to obtain the results in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the total purchase value column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
sn_stats = purchase_data_df.groupby("SN")
purchase_count_spenders = sn_stats["Purchase ID"].count()
average_purchase_price_spenders = sn_stats["Price"].mean()
total_purchase_value_spenders = sn_stats["Price"].sum()

top_spenders_df = pd.DataFrame({"Purchase Count":purchase_count_spenders,
                                "Average Purchase Price":average_purchase_price_spenders,
                                "Total Purchase Value":total_purchase_value_spenders
                                })
top_spenders_ordered_df = top_spenders_df.sort_values(["Total Purchase Value"], ascending=False)
top_spenders_ordered_df
# Out:
#              Purchase Count  Average Purchase Price  Total Purchase Value
# SN
# Lisosia93                 5                3.792000                 18.96
# Idastidru52               4                3.862500                 15.45
# Chamjask73                3                4.610000                 13.83
# Iral74                    4                3.405000                 13.62
# Iskadarya95               3                4.366667                 13.10
# ...                     ...                     ...                   ...
# Ililsasya43               1                1.020000                  1.02
# Irilis75                  1                1.020000                  1.02
# Aidai61                   1                1.010000                  1.01
# Chanirra79                1                1.010000                  1.01
# Alo38                     1                1.000000                  1.00
#
# [576 rows x 3 columns]

# %% [markdown]
# ## Most Popular Items

# %% [markdown]
# * Retrieve the Item ID, Item Name, and Item Price columns
#
#
# * Group by Item ID and Item Name. Perform calculations to obtain purchase count, average item price, and total purchase value
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the purchase count column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
item_stats_df = purchase_data_df.groupby(["Item ID","Item Name","Price"])

purchase_count_item = item_stats_df["Price"].count()
total_purchase_value_item = item_stats_df["Price"].sum()
item_price = total_purchase_value_item/purchase_count_item
most_popular_item_df = pd.DataFrame({"Purchase Count":purchase_count_item,
                                     "Item Price":item_price,
                                     "Total Purchase Value":total_purchase_value_item
                                    })

most_popular_item_ordered_df = most_popular_item_df.sort_values(["Purchase Count"],ascending=False)
most_popular_item_ordered_df
# Out:
#                                                             Purchase Count  \
# Item ID Item Name                                    Price
# 178     Oathbreaker, Last Hope of the Breaking Storm 4.23               12
# 108     Extraction, Quickblade Of Trembling Hands    3.53                9
# 145     Fiery Glass Crusader                         4.58                9
# 82      Nirvana                                      4.90                9
# 37      Shadow Strike, Glory of Ending Hope          3.16                8
# ...                                                                    ...
# 27      Riddle, Tribute of Ended Dreams              3.30                1
# 30      Stormcaller                                  3.36                1
# 126     Exiled Mithril Longsword                     2.00                1
# 51      Endbringer                                   4.66                1
# 91      Celeste                                      4.17                1
#
# ...

# %% [markdown]
# ## Most Profitable Items

# %% [markdown]
# * Sort the above table by total purchase value in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the data frame

# %%
most_profitable_items_df = most_popular_item_ordered_df.sort_values(["Total Purchase Value"],ascending=False)
most_profitable_items_df
# Out:
#                                                             Purchase Count  \
# Item ID Item Name                                    Price
# 178     Oathbreaker, Last Hope of the Breaking Storm 4.23               12
# 82      Nirvana                                      4.90                9
# 145     Fiery Glass Crusader                         4.58                9
# 92      Final Critic                                 4.88                8
# 103     Singed Scalpel                               4.35                8
# ...                                                                    ...
# 126     Exiled Mithril Longsword                     2.00                1
# 125     Whistling Mithril Warblade                   1.00                2
# 1       Crucifer                                     1.99                1
# 104     Gladiator's Glaive                           1.93                1
# 42      The Decapitator                              1.75                1
#
# ...
